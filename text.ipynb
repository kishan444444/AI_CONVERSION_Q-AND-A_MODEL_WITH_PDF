# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in f:\conversion qanda model with pdf\venv\lib\site-packages (0.3.17)
# Requirement already satisfied: PyYAML>=5.3 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (0.3.33)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (0.3.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\conversion qanda model with pdf\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\conversion qanda model with pdf\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\conversion qanda model with pdf\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\conversion qanda model with pdf\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in f:\conversion qanda model with pdf\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\conversion qanda model with pdf\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in f:\conversion qanda model with pdf\venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\conversion qanda model with pdf\venv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\conversion qanda model with pdf\venv\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in f:\conversion qanda model with pdf\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in f:\conversion qanda model with pdf\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in f:\conversion qanda model with pdf\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\conversion qanda model with pdf\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in f:\conversion qanda model with pdf\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in f:\conversion qanda model with pdf\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in f:\conversion qanda model with pdf\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain, create_history_aware_retriever
from langchain.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
from langchain_community.vectorstores import Chroma
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import MessagesPlaceholder  # Import missing dependency
import fitz  # PyMuPDF
import os
from dotenv import load_dotenv


load_dotenv()  # Load environment variables

# Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

groq_api_key = os.getenv("GROQ_API_KEY")

# Function to extract text from PDFs
def extract_text_from_pdf(uploaded_files):
    all_text = ""
    for uploaded_file in uploaded_files:
        doc = fitz.open(stream=uploaded_file.read(), filetype="pdf")
        all_text += "\n".join([page.get_text() for page in doc]) + "\n"
    return all_text

# Function to process PDF files and answer queries
def process_pdfs_and_query(uploaded_files, query):
    if uploaded_files:
        pdf_contents = extract_text_from_pdf(uploaded_files)
        
        # Split the text into chunks
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
        split_texts = text_splitter.split_text(pdf_contents)

        embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
        db = Chroma.from_texts(split_texts, embeddings)

        retriever = db.as_retriever()
        model = ChatGroq(model="Gemma2-9b-It", groq_api_key=groq_api_key)

        # Contextualization prompt
        contextualize_q_system_prompt = (
            "Given a chat history and the latest user question "
            "which might reference context in the chat history, "
            "formulate a standalone question which can be understood "
            "without the chat history. Do NOT answer the question, "
            "just reformulate it if needed and otherwise return it as is."
        )
        contextualize_q_prompt = ChatPromptTemplate.from_messages(
            [
                ("system", contextualize_q_system_prompt),
                MessagesPlaceholder(variable_name="chat_history"),  # Fixed placeholder
                ("human", "{input}"),
            ]
        )

        history_aware_retriever = create_history_aware_retriever(model, retriever, contextualize_q_prompt)

        # System prompt for answering questions
        system_prompt = "You are an AI assistant that helps summarize and answer questions from documents."

        qa_prompt = ChatPromptTemplate.from_messages(
            [
                ("system", system_prompt),
                MessagesPlaceholder(variable_name="chat_history"),
                ("human", "{input}"),
            ]
        )

        question_answer_chain = create_stuff_documents_chain(model, qa_prompt)
        rag_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

        chat_history = []
        response = rag_chain.invoke({"input": query, "chat_history": chat_history})

        return response['answer']  # Ensure function returns the answer

# Example usage
if __name__ == "__main__":
    with open("Attention.pdf", "rb") as file:
        uploaded_files = [file]
        query = "What is the main point of the document?"

        answer = process_pdfs_and_query(uploaded_files, query)
        print("Answer:", answer)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 8
#       6 from langchain.embeddings import SentenceTransformerEmbeddings
#       7 from langchain.text_splitter import RecursiveCharacterTextSplitter
# ----> 8 from langchain.schema import MessagesPlaceholder  # Import missing dependency
#       9 import fitz  # PyMuPDF
#      10 import os
#
# ImportError: cannot import name 'MessagesPlaceholder' from 'langchain.schema' (f:\CONVERSION QandA model with pdf\venv\lib\site-packages\langchain\schema\__init__.py)

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain, create_history_aware_retriever
from langchain.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
from langchain_community.vectorstores import Chroma
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.prompts import MessagesPlaceholder  # Correct import
import fitz  # PyMuPDF
import os
from dotenv import load_dotenv

load_dotenv()  # Load environment variables

# Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

groq_api_key = os.getenv("GROQ_API_KEY")

# Function to extract text from PDFs
def extract_text_from_pdf(uploaded_files):
    all_text = ""
    for uploaded_file in uploaded_files:
        doc = fitz.open(stream=uploaded_file.read(), filetype="pdf")
        all_text += "\n".join([page.get_text() for page in doc]) + "\n"
    return all_text

# Function to process PDF files and answer queries
def process_pdfs_and_query(uploaded_files, query):
    if uploaded_files:
        pdf_contents = extract_text_from_pdf(uploaded_files)
        
        # Split the text into chunks
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
        split_texts = text_splitter.split_text(pdf_contents)

        embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
        db = Chroma.from_texts(split_texts, embeddings)

        retriever = db.as_retriever()
        model = ChatGroq(model="Gemma2-9b-It", groq_api_key=groq_api_key)

        # Contextualization prompt
        contextualize_q_system_prompt = (
            "Given a chat history and the latest user question "
            "which might reference context in the chat history, "
            "formulate a standalone question which can be understood "
            "without the chat history. Do NOT answer the question, "
            "just reformulate it if needed and otherwise return it as is."
        )
        contextualize_q_prompt = ChatPromptTemplate.from_messages(
            [
                ("system", contextualize_q_system_prompt),
                MessagesPlaceholder(variable_name="chat_history"),  # Corrected import
                ("human", "{input}"),
            ]
        )

        history_aware_retriever = create_history_aware_retriever(model, retriever, contextualize_q_prompt)

        # System prompt for answering questions
        system_prompt = "You are an AI assistant that helps summarize and answer questions from documents."

        qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human", "{input}"),
        ("assistant", "{context}")  # Ensure the `context` variable is present
    ]
)


        question_answer_chain = create_stuff_documents_chain(model, qa_prompt)
        rag_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

        chat_history = []
        response = rag_chain.invoke({"input": query, "chat_history": chat_history})

        return response['answer']  # Ensure function returns the answer

# Example usage
if __name__ == "__main__":
    with open("Attention.pdf", "rb") as file:
        uploaded_files = [file]
        query = "What is the main point of the document?"

        answer = process_pdfs_and_query(uploaded_files, query)
        print("Answer:", answer)
# Out:
# Answer:
#
# This excerpt appears to be a list of references for a paper or document. Each reference includes:
#
# * **Authors:** The names of the researchers who wrote the paper.
# * **Title:** A brief description of the paper's topic.
# * **Publication details:** Information about where the paper was published, including the journal name, volume, issue, pages, and year.
#
# **Therefore, the main point of this document excerpt is to provide a list of cited sources for further reading.**
